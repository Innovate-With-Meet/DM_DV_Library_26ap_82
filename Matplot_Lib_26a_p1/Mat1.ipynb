# %%
import matplotlib.pyplot as plt
# import the matlib

# %%
x = [10,20,30,40,50]
y = [1,2,3,4,5]
# define the dataset

# %%
# plt.plot(x,y)
plt.scatter(x,y)
# plt.bar(x,y)
plt.grid(True)
plt.show()
# define scatter plot
